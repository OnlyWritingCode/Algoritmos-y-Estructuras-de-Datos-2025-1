# %% [markdown]
# # 🔁 Ejercicio 1: De Lista Enlazada a Lista Doblemente Enlazada
#
# Queremos transformar una **lista enlazada** en una **lista doblemente enlazada**, como se muestra en el siguiente esquema:
#
# 📌 **Diagrama de referencia**:
#
# ![Diagrama sin título.drawio (1).png](data:image/png;base64,...)
#
# Dado un arreglo de números enteros, la meta es:
#
# ## 🎯 Objetivo
#
# 1. Completar la clase `Nodo` y `ListaDoblementeEnlazada` para agregar correctamente cada nodo en ambas direcciones (`siguiente` y `anterior`).
# 2. Implementar una función que permita **imprimir todos los valores desde el primero hasta el último**, y luego desde el último hasta el primero (recorrido en reversa).
#
# ---
#
# ### 🧪 Salidas esperadas:
# Ej:
# ```
# valores = [23, 45, 654, 1, 34, 54, 213]
# lista = ListaDoblementeEnlazada()
# ```
# ```
# De inicio a fin:
# 23
# 45
# 654
# 1
# 34
# 54
# 213
#
# De fin a inicio:
# 213
# 54
# 34
# 1
# 654
# 45
# 23
# ```

# %%
class Nodo:
    def __init__(self, valor):
        #DEBEN AGREGAR ALGO
        self.valor = valor
        self.siguiente = None
        self.anterior = None  # completar como parte del ejercicio

class ListaDoblementeEnlazada:
    def __init__(self):
        #DEBEN AGREGAR ALGO
        self.cabeza = None
        self.cola = None  # para poder volver al final

    def agregar(self, valor):
        nuevo = Nodo(valor)
        if self.cabeza is None:
            self.cabeza = nuevo
            self.cola = nuevo
        else:
            #DEBEN AGREGAR ALGO
            self.cola.siguiente = nuevo
            nuevo.anterior = self.cola  # ← completar enlace hacia atrás
            self.cola = nuevo

    def imprimir_ida(self):
        # TODO: implementar impresión desde cabeza hasta cola
        actual = self.cabeza
        while actual:
            print(actual.valor)
            actual = actual.siguiente

    def imprimir_vuelta(self):
        # TODO: implementar impresión desde cola hasta cabeza
        actual = self.cola
        while actual:
            print(actual.valor)
            actual = actual.anterior

    #OPCIONAL
    def imprimir_ida_y_vuelta(self):
    # Recorrido desde cabeza a cola
        print("De inicio a fin:")
        actual = self.cabeza
        while actual:
            print(actual.valor)
            actual = actual.siguiente

        print("\nDe fin a inicio:")
        actual = self.cola
        while actual:
            print(actual.valor)
            actual = actual.anterior

# %%
# Prueba
valores = [23, 45, 654, 1, 34, 54, 213]
lista = ListaDoblementeEnlazada()

for v in valores:
    lista.agregar(v)

print("De inicio a fin:")
lista.imprimir_ida()

print("\nDe fin a inicio:")
lista.imprimir_vuelta()
# Out:
# De inicio a fin:
# 23
# 45
# 654
# 1
# 34
# 54
# 213
#
# De fin a inicio:
# 213
# 54
# 34
# 1
# 654
# 45
# 23

# %%
lista.imprimir_ida_y_vuelta()
# Out:
# De inicio a fin:
# 23
# 45
# 654
# 1
# 34
# 54
# 213
#
# De fin a inicio:
# 213
# 54
# 34
# 1
# 654
# 45
# 23
